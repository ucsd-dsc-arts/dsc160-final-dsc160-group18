# %%
import os
from io import StringIO, BytesIO
import IPython.display
import numpy as np
import PIL.Image
from PIL import Image
from scipy.stats import truncnorm
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt
import imghdr
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed

# %%
dirpath = r"\Users\brian\Documents\dsc160-final-dsc160-group18\data\albums"
thepath = r"\Users\brian\Documents\dsc160-final-dsc160-group18\data\512albums"

# %%
def make_thumbnail(filename, imagepath, newpath):
    #print(imagepath + "\\" + filename)
    temp = imagepath + "\\" + filename
    img = Image.open(temp)
    size = 512,512
    img.thumbnail(size)
    img.save(newpath + "\\" + filename)

# %%
directory = imagepath = os.fsencode(r"C:\\Users\brian\Documents\dsc160-final-dsc160-group18\data\albums")
for file in os.listdir(directory):
    make_thumbnail(file.decode('utf-8'), dirpath, thepath)

# %%
from os import listdir
dirt = r"C:\\Users\brian\Documents\dsc160-final-dsc160-group18\data\512albums"
from numpy import asarray
def load_images(path, size=(512,512)):
    temp = list()
    for filename in listdir(path):
        pixels = load_img(path + "\\" + filename, target_size=size)
        pixels = img_to_array(pixels)
        temp.append(pixels)
    return asarray(temp)

data = load_images(dirt)
filename = 'albums.npz'
savez_compressed(filename, data)

# %%
from numpy import load
from matplotlib import pyplot
data = load('albums.npz')
images = data['arr_0']
images.shape
# Out:
# (96, 512, 512, 3)

# %%
n_samples = 5
for i in range(n_samples):
    pyplot.subplot(2, n_samples, 1 + i)
    pyplot.axis('off')
    pyplot.imshow(images[i].astype('uint8'))
pyplot.show()

# %%
images
# Out:
# array([[[[ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          ...,
#          [167., 142., 138.],
#          [231., 200., 198.],
#          [231., 200., 198.]],
#
#         [[ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          ...,
#          [167., 142., 138.],
#          [231., 200., 198.],
#          [231., 200., 198.]],
#
#         [[ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          [ 69.,  64.,  60.],
#          ...,
#          [243., 218., 214.],
#          [179., 149., 147.],
#          [179., 149., 147.]],
#
#         ...,
#
#         [[164., 139., 135.],
#          [164., 139., 135.],
#          [245., 220., 216.],
#          ...,
#          [ 23.,  19.,  16.],
#          [ 23.,  19.,  16.],
#          [ 23.,  19.,  16.]],
#
#         [[232., 201., 199.],
#          [232., 201., 199.],
#          [179., 149., 147.],
#          ...,
#          [ 23.,  19.,  16.],
#          [ 24.,  20.,  17.],
#          [ 24.,  20.,  17.]],
#
#         [[232., 201., 199.],
#          [232., 201., 199.],
#          [179., 149., 147.],
#          ...,
#          [ 23.,  19.,  16.],
#          [ 24.,  20.,  17.],
#          [ 24.,  20.,  17.]]],
#
#
#        [[[ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          [ 19.,  19.,  19.],
#          ...,
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.]],
#
#         [[ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          ...,
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.]],
#
#         [[ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          [ 20.,  20.,  20.],
#          ...,
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.],
#          [ 18.,  18.,  18.]],
#
#         ...,
#
#         [[ 17.,  17.,  17.],
#          [ 17.,  17.,  17.],
#          [ 16.,  16.,  16.],
#          ...,
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.]],
#
#         [[ 17.,  17.,  17.],
#          [ 17.,  17.,  17.],
#          [ 16.,  16.,  16.],
#          ...,
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.]],
#
#         [[ 17.,  17.,  17.],
#          [ 17.,  17.,  17.],
#          [ 16.,  16.,  16.],
#          ...,
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.],
#          [ 16.,  16.,  16.]]],
#
#
#        [[[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         ...,
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]],
#
#         [[254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.],
#          ...,
#          [254., 254., 254.],
#          [254., 254., 254.],
#          [254., 254., 254.]]],
#
#
#        ...,
#
#
#        [[[134., 134., 134.],
#          [134., 134., 134.],
#          [134., 134., 134.],
#          ...,
#          [197., 197., 197.],
#          [197., 197., 197.],
#          [197., 197., 197.]],
#
#         [[134., 134., 134.],
#          [134., 134., 134.],
#          [134., 134., 134.],
#          ...,
#          [197., 197., 197.],
#          [197., 197., 197.],
#          [197., 197., 197.]],
#
#         [[134., 134., 134.],
#          [134., 134., 134.],
#          [134., 134., 132.],
#          ...,
#          [197., 197., 197.],
#          [197., 197., 197.],
#          [197., 197., 197.]],
#
#         ...,
#
#         [[199., 199., 199.],
#          [199., 199., 199.],
#          [199., 199., 199.],
#          ...,
#          [240., 240., 240.],
#          [240., 240., 240.],
#          [240., 240., 240.]],
#
#         [[199., 199., 199.],
#          [199., 199., 199.],
#          [199., 199., 199.],
#          ...,
#          [240., 240., 240.],
#          [240., 240., 240.],
#          [240., 240., 240.]],
#
#         [[199., 199., 199.],
#          [199., 199., 199.],
#          [199., 199., 199.],
#          ...,
#          [240., 240., 240.],
#          [240., 240., 240.],
#          [240., 240., 240.]]],
#
#
#        [[[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]],
#
#         ...,
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]],
#
#         [[255., 255., 255.],
#          [255., 255., 255.],
#          [255., 255., 255.],
#          ...,
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.],
#          [  0.,   0.,   0.]]],
#
#
#        [[[125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.],
#          ...,
#          [125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.]],
#
#         [[125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.],
#          ...,
#          [125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.]],
#
#         [[125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.],
#          ...,
#          [125., 158., 212.],
#          [125., 158., 212.],
#          [125., 158., 212.]],
#
#         ...,
#
#         [[171., 103.,  68.],
#          [172., 106.,  74.],
#          [165.,  99.,  73.],
#          ...,
#          [162., 100.,  63.],
#          [159.,  97.,  58.],
#          [156.,  94.,  55.]],
#
#         [[166.,  98.,  63.],
#          [162.,  95.,  66.],
#          [166., 100.,  78.],
#          ...,
#          [163., 101.,  64.],
#          [162., 100.,  63.],
#          [161.,  99.,  60.]],
#
#         [[157.,  91.,  56.],
#          [157.,  90.,  61.],
#          [175., 109.,  87.],
#          ...,
#          [167., 105.,  68.],
#          [169., 107.,  70.],
#          [169., 107.,  68.]]]], dtype=float32)

# %%
import os
import glob
os.environ["KERAS_BACKEND"] = "tensorflow"
import numpy as np
from sklearn.utils import shuffle
import time
import cv2
import scipy
import imageio
from PIL import Image
import matplotlib.gridspec as gridspec
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers.core import Activation
from keras.layers.normalization import BatchNormalization
from keras.layers.convolutional import UpSampling2D
from keras.layers.pooling import MaxPooling2D
from keras.layers.core import Flatten
from keras.layers import Input
from keras.layers import Conv2D, Conv2DTranspose, Dropout
from keras.models import Model
from keras.optimizers import SGD, Adam, RMSprop
from keras.layers.advanced_activations import LeakyReLU
#from GAN_Nets import get_disc_normal, get_gen_normal
import matplotlib.pyplot as plt
from keras.models import load_model
import keras.backend as K
#from scipy.interpolate import spline
#K.set_image_dim_ordering('tf')

# %%
def norm_img(img):
    '''A function to Normalize Images.
    Input:
        img : Original image as numpy array.
    Output: Normailized Image as numpy array
    '''
    img = (img / 127.5) - 1
    return img
def denorm_img(img):
    '''A function to Denormailze, i.e. recreate image from normalized image
    Input:
        img : Normalized image as numpy array.
    Output: Original Image as numpy array
    '''
    img = (img + 1) * 127.5
    return img.astype(np.uint8) 
def sample_from_dataset(batch_size, image_shape, data_dir):
    '''Create a batch of image samples by sampling random images from a data directory.
    Resizes the image using image_shape and normalize the images.
    Input:
        batch_size : Sample size required
        image_size : Size that Image should be resized to
        data_dir : Path of directory where training images are placed.
    Output:
        sample : batch of processed images 
    '''
    sample_dim = (batch_size,) + image_shape
    sample = np.empty(sample_dim, dtype=np.float32)
    all_data_dirlist = list(glob.glob(data_dir + '*/*.jpg'))
    sample_imgs_paths = np.random.choice(all_data_dirlist,batch_size)
    for index,img_filename in enumerate(sample_imgs_paths):
        image = Image.open(img_filename)
        image = image.resize(image_shape[:-1])
        image = image.convert('RGB') 
        image = np.asarray(image)
        image = norm_img(image)
        sample[index,...] = image
    return sample

# %%
def generate_images(generator, save_dir):
    noise = gen_noise(batch_size,noise_shape)
    #using noise produced by np.random.uniform - the generator seems to produce same image for ANY noise - 
    #but those images (even though they are the same) are very close to the actual image - experiment with it later.
    fake_data_X = generator.predict(noise)
    print("Displaying generated images")
    plt.figure(figsize=(4,4))
    gs1 = gridspec.GridSpec(4, 4)
    gs1.update(wspace=0, hspace=0)
    rand_indices = np.random.choice(fake_data_X.shape[0],16,replace=False)
    for i in range(16):
        #plt.subplot(4, 4, i+1)
        ax1 = plt.subplot(gs1[i])
        ax1.set_aspect('equal')
        rand_index = rand_indices[i]
        image = fake_data_X[rand_index, :,:,:]
        fig = plt.imshow(denorm_img(image))
        plt.axis('off')
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
    plt.tight_layout()
    plt.savefig(save_dir+str(time.time())+"_GENERATEDimage.png",bbox_inches='tight',pad_inches=0)
    plt.show()

# %%
def save_img_batch(img_batch,img_save_dir):
    plt.figure(figsize=(4,4))
    gs1 = gridspec.GridSpec(4, 4)
    gs1.update(wspace=0, hspace=0)
    rand_indices = np.random.choice(img_batch.shape[0],16,replace=False)
    #print(rand_indices)
    for i in range(16):
        #plt.subplot(4, 4, i+1)
        ax1 = plt.subplot(gs1[i])
        ax1.set_aspect('equal')
        rand_index = rand_indices[i]
        image = img_batch[rand_index, :,:,:]
        fig = plt.imshow(denorm_img(image))
        plt.axis('off')
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
    plt.tight_layout()
    plt.savefig(img_save_dir,bbox_inches='tight',pad_inches=0)
    plt.show()

# %%
def gen_noise(batch_size, noise_shape):
    ''' Generates a numpy vector sampled from normal distribution of shape                                (batch_size,noise_shape)
    Input:
        batch_size : size of batch
        noise_shape: shape of noise vector, normally kept as 100 
    Output:a numpy vector sampled from normal distribution of shape                                  (batch_size,noise_shape)     
    '''
    return np.random.normal(0, 1, size=(batch_size,)+noise_shape)

# %%
def get_gen_normal(noise_shape):
    ''' This function takes as input shape of the noise vector and creates the Keras generator    architecture.
    '''
    kernel_init = 'glorot_uniform'    
    gen_input = Input(shape = noise_shape) 
    
    # Transpose 2D conv layer 1. 
    generator = Conv2DTranspose(filters = 512, kernel_size = (4,4), strides = (1,1), padding = "valid", data_format = "channels_last", kernel_initializer = kernel_init)(gen_input)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 2.
    generator = Conv2DTranspose(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 3.
    generator = Conv2DTranspose(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Transpose 2D conv layer 4.
    generator = Conv2DTranspose(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # conv 2D layer 1.
    generator = Conv2D(filters = 64, kernel_size = (3,3), strides = (1,1), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    generator = BatchNormalization(momentum = 0.5)(generator)
    generator = LeakyReLU(0.2)(generator)
    
    # Final Transpose 2D conv layer 5 to generate final image. Filter size 3 for 3 image channel
    generator = Conv2DTranspose(filters = 3, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(generator)
    
    # Tanh activation to get final normalized image
    generator = Activation('tanh')(generator)
    
    # defining the optimizer and compiling the generator model.
    gen_opt = Adam(lr=0.00015, beta_1=0.5)
    generator_model = Model(inputs = gen_input, output = generator)
    generator_model.compile(loss='binary_crossentropy', optimizer=gen_opt, metrics=['accuracy'])
    generator_model.summary()
    return generator_model

# %%
def get_disc_normal(image_shape=(64,64,3)):
    dropout_prob = 0.4
    kernel_init = 'glorot_uniform'
    dis_input = Input(shape = image_shape)
    
    # Conv layer 1:
    discriminator = Conv2D(filters = 64, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(dis_input)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 2:
    discriminator = Conv2D(filters = 128, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 3:   
    discriminator = Conv2D(filters = 256, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)
    # Conv layer 4:
    discriminator = Conv2D(filters = 512, kernel_size = (4,4), strides = (2,2), padding = "same", data_format = "channels_last", kernel_initializer = kernel_init)(discriminator)
    discriminator = BatchNormalization(momentum = 0.5)(discriminator)
    discriminator = LeakyReLU(0.2)(discriminator)#discriminator = MaxPooling2D(pool_size=(2, 2))(discriminator)
    # Flatten
    discriminator = Flatten()(discriminator)
    # Dense Layer
    discriminator = Dense(1)(discriminator)
    # Sigmoid Activation
    discriminator = Activation('sigmoid')(discriminator)
    # Optimizer and Compiling model
    dis_opt = Adam(lr=0.0002, beta_1=0.5)
    discriminator_model = Model(inputs = dis_input, output = discriminator)
    discriminator_model.compile(loss='binary_crossentropy', optimizer=dis_opt, metrics=['accuracy'])
    discriminator_model.summary()
    return discriminator_model

# %%
noise_shape = (1,1,100)
num_steps = 510
batch_size = 64
image_shape = None
img_save_dir = dirt = r"C:\\Users\brian\Documents\dsc160-final-dsc160-group18\data\output"
save_model = True
image_shape = (64, 64, 3)
data_dir = r"C:\\Users\brian\Documents\dsc160-final-dsc160-group18\data\512albums"

log_dir = img_save_dir
save_model_dir = img_save_dir

# %%
discriminator = get_disc_normal(image_shape)
generator = get_gen_normal(noise_shape)
# Out:
# C:\Users\brian\anaconda3\lib\site-packages\ipykernel_launcher.py:29: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`
# Model: "model_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 32, 32, 64)        3136
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 16, 16, 128)       131200
# _________________________________________________________________
# batch_normalization_25 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_29 (LeakyReLU)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 8, 8, 256)         524544
# _________________________________________________________________
# batch_normalization_26 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_30 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 512)         2097664
# _________________________________________________________________
# batch_normalization_27 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_31 (LeakyReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 8193
# _________________________________________________________________
# activation_7 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,768,321
# Trainable params: 2,766,529
# Non-trainable params: 1,792
# _________________________________________________________________
# Model: "model_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        (None, 1, 1, 100)         0
# _________________________________________________________________
# conv2d_transpose_16 (Conv2DT (None, 4, 4, 512)         819712
# _________________________________________________________________
# batch_normalization_28 (Batc (None, 4, 4, 512)         2048
# _________________________________________________________________
# leaky_re_lu_32 (LeakyReLU)   (None, 4, 4, 512)         0
# _________________________________________________________________
# conv2d_transpose_17 (Conv2DT (None, 8, 8, 256)         2097408
# _________________________________________________________________
# batch_normalization_29 (Batc (None, 8, 8, 256)         1024
# _________________________________________________________________
# leaky_re_lu_33 (LeakyReLU)   (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_transpose_18 (Conv2DT (None, 16, 16, 128)       524416
# _________________________________________________________________
# batch_normalization_30 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# leaky_re_lu_34 (LeakyReLU)   (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_transpose_19 (Conv2DT (None, 32, 32, 64)        131136
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_35 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 32, 32, 64)        256
# _________________________________________________________________
# leaky_re_lu_36 (LeakyReLU)   (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_transpose_20 (Conv2DT (None, 64, 64, 3)         3075
# _________________________________________________________________
# activation_8 (Activation)    (None, 64, 64, 3)         0
# =================================================================
# Total params: 3,616,771
# Trainable params: 3,614,723
# Non-trainable params: 2,048
# _________________________________________________________________
# C:\Users\brian\anaconda3\lib\site-packages\ipykernel_launcher.py:40: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ac...)`

# %%
discriminator.trainable = False

# Optimizer for the GAN
opt = Adam(lr=0.00015, beta_1=0.5) #same as generator
# Input to the generator
gen_inp = Input(shape=noise_shape)

GAN_inp = generator(gen_inp)
GAN_opt = discriminator(GAN_inp)

# Final GAN
gan = Model(input = gen_inp, output = GAN_opt)
gan.compile(loss = 'binary_crossentropy', optimizer = opt, metrics=['accuracy'])

#plot_model(gan, to_file='gan_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# C:\Users\brian\anaconda3\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("mo...)`
#   if sys.path[0] == '':

# %%
# Use a fixed noise vector to see how the GAN Images transition through time on a fixed noise. 
fixed_noise = gen_noise(16,noise_shape)

# To keep Track of losses
avg_disc_fake_loss = []
avg_disc_real_loss = []
avg_GAN_loss = []

# We will run for num_steps iterations
for step in range(num_steps): 
    tot_step = step
    print("Begin step: ", tot_step)
    # to keep track of time per step
    step_begin_time = time.time() 
    
    # sample a batch of normalized images from the dataset
    real_data_X = sample_from_dataset(batch_size, image_shape, data_dir=data_dir)
    
    # Genearate noise to send as input to the generator
    noise = gen_noise(batch_size,noise_shape)
    
    # Use generator to create(predict) images
    fake_data_X = generator.predict(noise)
    
    # Save predicted images from the generator every 10th step
    if (tot_step % 100) == 0:
        step_num = str(tot_step).zfill(4)
        save_img_batch(fake_data_X,img_save_dir+step_num+"_image.jpg")
    
    # Create the labels for real and fake data. We don't give exact ones and zeros but add a small amount of noise. This is an important GAN training trick
    real_data_Y = np.ones(batch_size) - np.random.random_sample(batch_size)*0.2
    fake_data_Y = np.random.random_sample(batch_size)*0.2
        
    # train the discriminator using data and labels

    discriminator.trainable = True
    generator.trainable = False

    # Training Discriminator seperately on real data
    dis_metrics_real = discriminator.train_on_batch(real_data_X,real_data_Y) 
    # training Discriminator seperately on fake data
    dis_metrics_fake = discriminator.train_on_batch(fake_data_X,fake_data_Y) 
    
    print("Disc: real loss: %f fake loss: %f" % (dis_metrics_real[0], dis_metrics_fake[0]))
    
    # Save the losses to plot later
    avg_disc_fake_loss.append(dis_metrics_fake[0])
    avg_disc_real_loss.append(dis_metrics_real[0])
    
    # Train the generator using a random vector of noise and its labels (1's with noise)
    generator.trainable = True
    discriminator.trainable = False

    GAN_X = gen_noise(batch_size,noise_shape)
    GAN_Y = real_data_Y
   
    gan_metrics = gan.train_on_batch(GAN_X,GAN_Y)
    print("GAN loss: %f" % (gan_metrics[0]))
    
    # Log results by opening a file in append mode
    text_file = open(log_dir+"\\training_log.txt", "a")
    text_file.write("Step: %d Disc: real loss: %f fake loss: %f GAN loss: %f\n" % (tot_step, dis_metrics_real[0], dis_metrics_fake[0],gan_metrics[0]))
    text_file.close()

    # save GAN loss to plot later
    avg_GAN_loss.append(gan_metrics[0])
            
    end_time = time.time()
    diff_time = int(end_time - step_begin_time)
    print("Step %d completed. Time took: %s secs." % (tot_step, diff_time))
    
    # save model at every 500 steps
    if ((tot_step+1) % 500) == 0:
        print("-----------------------------------------------------------------")
        print("Average Disc_fake loss: %f" % (np.mean(avg_disc_fake_loss))) 
        print("Average Disc_real loss: %f" % (np.mean(avg_disc_real_loss))) 
        print("Average GAN loss: %f" % (np.mean(avg_GAN_loss)))
        print("-----------------------------------------------------------------")
        discriminator.trainable = False
        generator.trainable = False
        # predict on fixed_noise
        fixed_noise_generate = generator.predict(noise)
        step_num = str(tot_step).zfill(4)
        save_img_batch(fixed_noise_generate,img_save_dir+step_num+"fixed_image.png")
        generator.save(save_model_dir+str(tot_step)+"_GENERATOR_weights_and_arch.hdf5")
        discriminator.save(save_model_dir+str(tot_step)+"_DISCRIMINATOR_weights_and_arch.hdf5")
# Out:
# Begin step:  0
# Disc: real loss: 0.949895 fake loss: 2.679638
# GAN loss: 1.924687
# Step 0 completed. Time took: 19 secs.
# Begin step:  1
# Disc: real loss: 0.711592 fake loss: 1.866756
# GAN loss: 3.745121
# Step 1 completed. Time took: 7 secs.
# Begin step:  2
# Disc: real loss: 0.610118 fake loss: 1.020592
# GAN loss: 1.693125
# Step 2 completed. Time took: 6 secs.
# Begin step:  3
# Disc: real loss: 0.514845 fake loss: 0.396726
# GAN loss: 0.387055
# Step 3 completed. Time took: 6 secs.
# Begin step:  4
# Disc: real loss: 0.441334 fake loss: 2.189368
# GAN loss: 2.652614
# Step 4 completed. Time took: 6 secs.
# Begin step:  5
# Disc: real loss: 0.590371 fake loss: 0.504933
# GAN loss: 3.347539
# Step 5 completed. Time took: 6 secs.
# Begin step:  6
# Disc: real loss: 0.600849 fake loss: 0.574441
# GAN loss: 2.620194
# Step 6 completed. Time took: 6 secs.
# Begin step:  7
# Disc: real loss: 0.561358 fake loss: 0.594378
# GAN loss: 4.588887
# Step 7 completed. Time took: 6 secs.
# Begin step:  8
# Disc: real loss: 0.419589 fake loss: 0.410004
# GAN loss: 3.631892
# Step 8 completed. Time took: 6 secs.
# Begin step:  9
# Disc: real loss: 0.396279 fake loss: 0.769286
# GAN loss: 6.101717
# Step 9 completed. Time took: 6 secs.
# Begin step:  10
# Disc: real loss: 0.587479 fake loss: 0.624221
# GAN loss: 4.914493
# Step 10 completed. Time took: 6 secs.
# Begin step:  11
# Disc: real loss: 0.359960 fake loss: 0.489849
# GAN loss: 4.038319
# Step 11 completed. Time took: 6 secs.
# Begin step:  12
# Disc: real loss: 0.334497 fake loss: 0.372646
# GAN loss: 2.517092
# Step 12 completed. Time took: 6 secs.
# Begin step:  13
# Disc: real loss: 0.373378 fake loss: 1.148567
# GAN loss: 9.398058
# Step 13 completed. Time took: 6 secs.
# Begin step:  14
# Disc: real loss: 1.001141 fake loss: 1.185870
# GAN loss: 8.890596
# Step 14 completed. Time took: 6 secs.
# Begin step:  15
# Disc: real loss: 1.432503 fake loss: 0.371828
# GAN loss: 1.116194
# Step 15 completed. Time took: 6 secs.
# Begin step:  16
# Disc: real loss: 0.616645 fake loss: 3.288707
# GAN loss: 8.622907
# Step 16 completed. Time took: 7 secs.
# Begin step:  17
# Disc: real loss: 0.663859 fake loss: 1.204999
# GAN loss: 11.450215
# Step 17 completed. Time took: 6 secs.
# Begin step:  18
# Disc: real loss: 0.483907 fake loss: 0.875154
# GAN loss: 6.697450
# Step 18 completed. Time took: 6 secs.
# Begin step:  19
# Disc: real loss: 0.395051 fake loss: 0.433463
# GAN loss: 3.459049
# Step 19 completed. Time took: 7 secs.
# Begin step:  20
# Disc: real loss: 0.425933 fake loss: 0.523276
# GAN loss: 5.791241
# Step 20 completed. Time took: 7 secs.
# Begin step:  21
# Disc: real loss: 0.383958 fake loss: 0.539395
# GAN loss: 4.486653
# Step 21 completed. Time took: 8 secs.
# Begin step:  22
# Disc: real loss: 0.344686 fake loss: 0.548059
# GAN loss: 6.218450
# Step 22 completed. Time took: 7 secs.
# Begin step:  23
# Disc: real loss: 0.369320 fake loss: 0.568739
# GAN loss: 4.670824
# Step 23 completed. Time took: 7 secs.
# Begin step:  24
# Disc: real loss: 0.370269 fake loss: 0.534596
# GAN loss: 6.062088
# Step 24 completed. Time took: 6 secs.
# Begin step:  25
# Disc: real loss: 0.377349 fake loss: 0.734210
# GAN loss: 3.919418
# Step 25 completed. Time took: 6 secs.
# Begin step:  26
# Disc: real loss: 0.359354 fake loss: 0.960358
# GAN loss: 10.155624
# Step 26 completed. Time took: 6 secs.
# Begin step:  27
# Disc: real loss: 0.660465 fake loss: 1.325461
# GAN loss: 10.805693
# Step 27 completed. Time took: 6 secs.
# Begin step:  28
# Disc: real loss: 0.411624 fake loss: 0.742124
# GAN loss: 4.475113
# Step 28 completed. Time took: 6 secs.
# Begin step:  29
# Disc: real loss: 0.445431 fake loss: 0.813356
# GAN loss: 7.585335
# Step 29 completed. Time took: 6 secs.
# Begin step:  30
# Disc: real loss: 0.413821 fake loss: 0.918144
# GAN loss: 8.775377
# Step 30 completed. Time took: 6 secs.
# Begin step:  31
# Disc: real loss: 0.424054 fake loss: 0.662078
# GAN loss: 3.217619
# Step 31 completed. Time took: 6 secs.
# Begin step:  32
# Disc: real loss: 0.412081 fake loss: 1.151093
# GAN loss: 10.277730
# Step 32 completed. Time took: 6 secs.
# Begin step:  33
# Disc: real loss: 0.537093 fake loss: 1.492226
# GAN loss: 12.387075
# Step 33 completed. Time took: 6 secs.
# Begin step:  34
# Disc: real loss: 0.544049 fake loss: 1.008520
# GAN loss: 7.578924
# Step 34 completed. Time took: 6 secs.
# Begin step:  35
# Disc: real loss: 0.452699 fake loss: 0.455568
# GAN loss: 2.011065
# Step 35 completed. Time took: 6 secs.
# Begin step:  36
# Disc: real loss: 0.444121 fake loss: 1.755297
# GAN loss: 10.960541
# Step 36 completed. Time took: 7 secs.
# Begin step:  37
# Disc: real loss: 0.514073 fake loss: 1.490662
# GAN loss: 14.207006
# Step 37 completed. Time took: 6 secs.
# Begin step:  38
# Disc: real loss: 0.467399 fake loss: 1.604610
# GAN loss: 12.209457
# Step 38 completed. Time took: 6 secs.
# Begin step:  39
# Disc: real loss: 0.478836 fake loss: 0.864162
# GAN loss: 6.708282
# Step 39 completed. Time took: 6 secs.
# Begin step:  40
# Disc: real loss: 0.387217 fake loss: 0.429724
# GAN loss: 2.210871
# Step 40 completed. Time took: 6 secs.
# Begin step:  41
# Disc: real loss: 0.528764 fake loss: 1.272760
# GAN loss: 9.075121
# Step 41 completed. Time took: 6 secs.
# Begin step:  42
# Disc: real loss: 0.509201 fake loss: 1.372287
# GAN loss: 11.302526
# Step 42 completed. Time took: 6 secs.
# Begin step:  43
# Disc: real loss: 0.728785 fake loss: 0.919565
# GAN loss: 6.639606
# Step 43 completed. Time took: 6 secs.
# Begin step:  44
# Disc: real loss: 0.437740 fake loss: 0.382010
# GAN loss: 2.074086
# Step 44 completed. Time took: 6 secs.
# Begin step:  45
# Disc: real loss: 0.527532 fake loss: 1.157775
# GAN loss: 8.530144
# Step 45 completed. Time took: 6 secs.
# Begin step:  46
# Disc: real loss: 0.454866 fake loss: 1.369317
# GAN loss: 10.989938
# Step 46 completed. Time took: 6 secs.
# Begin step:  47
# Disc: real loss: 0.399321 fake loss: 1.025073
# GAN loss: 6.996437
# Step 47 completed. Time took: 7 secs.
# Begin step:  48
# Disc: real loss: 0.369365 fake loss: 0.495621
# GAN loss: 2.776747
# Step 48 completed. Time took: 6 secs.
# Begin step:  49
# Disc: real loss: 0.434681 fake loss: 0.902304
# GAN loss: 6.558414
# Step 49 completed. Time took: 6 secs.
# Begin step:  50
# Disc: real loss: 0.392277 fake loss: 1.035133
# GAN loss: 7.902627
# Step 50 completed. Time took: 6 secs.
# Begin step:  51
# Disc: real loss: 0.401847 fake loss: 0.693035
# GAN loss: 3.926046
# Step 51 completed. Time took: 6 secs.
# Begin step:  52
# Disc: real loss: 0.376024 fake loss: 0.383274
# GAN loss: 2.556296
# Step 52 completed. Time took: 6 secs.
# Begin step:  53
# Disc: real loss: 0.355301 fake loss: 0.377351
# GAN loss: 3.087740
# Step 53 completed. Time took: 6 secs.
# Begin step:  54
# Disc: real loss: 0.314974 fake loss: 0.402554
# GAN loss: 2.134498
# Step 54 completed. Time took: 6 secs.
# Begin step:  55
# Disc: real loss: 0.369141 fake loss: 0.572845
# GAN loss: 6.637352
# Step 55 completed. Time took: 6 secs.
# Begin step:  56
# Disc: real loss: 0.438628 fake loss: 0.878193
# GAN loss: 6.849356
# Step 56 completed. Time took: 6 secs.
# Begin step:  57
# Disc: real loss: 0.345156 fake loss: 0.575028
# GAN loss: 2.407210
# Step 57 completed. Time took: 6 secs.
# Begin step:  58
# Disc: real loss: 0.347285 fake loss: 1.272283
# GAN loss: 11.594013
# Step 58 completed. Time took: 6 secs.
# Begin step:  59
# Disc: real loss: 0.492665 fake loss: 1.722840
# GAN loss: 14.281631
# Step 59 completed. Time took: 7 secs.
# Begin step:  60
# Disc: real loss: 0.475135 fake loss: 1.575646
# GAN loss: 13.602922
# Step 60 completed. Time took: 6 secs.
# Begin step:  61
# Disc: real loss: 0.353591 fake loss: 1.348278
# GAN loss: 10.624256
# Step 61 completed. Time took: 6 secs.
# Begin step:  62
# Disc: real loss: 0.387613 fake loss: 0.870222
# GAN loss: 5.900761
# Step 62 completed. Time took: 6 secs.
# Begin step:  63
# Disc: real loss: 0.347822 fake loss: 0.432087
# GAN loss: 1.910395
# Step 63 completed. Time took: 6 secs.
# Begin step:  64
# Disc: real loss: 0.357763 fake loss: 1.030425
# GAN loss: 6.458531
# Step 64 completed. Time took: 6 secs.
# Begin step:  65
# Disc: real loss: 0.395934 fake loss: 1.083794
# GAN loss: 8.590943
# Step 65 completed. Time took: 6 secs.
# Begin step:  66
# Disc: real loss: 0.442693 fake loss: 0.750353
# GAN loss: 4.721561
# Step 66 completed. Time took: 6 secs.
# Begin step:  67
# Disc: real loss: 0.419936 fake loss: 0.408245
# GAN loss: 1.919986
# Step 67 completed. Time took: 6 secs.
# Begin step:  68
# Disc: real loss: 0.394500 fake loss: 0.631373
# GAN loss: 4.207985
# Step 68 completed. Time took: 6 secs.
# Begin step:  69
# Disc: real loss: 0.410972 fake loss: 0.551208
# GAN loss: 4.016563
# Step 69 completed. Time took: 6 secs.
# Begin step:  70
# Disc: real loss: 0.353562 fake loss: 0.370087
# GAN loss: 2.107052
# Step 70 completed. Time took: 6 secs.
# Begin step:  71
# Disc: real loss: 0.346110 fake loss: 0.640480
# GAN loss: 4.819408
# Step 71 completed. Time took: 6 secs.
# Begin step:  72
# Disc: real loss: 0.396847 fake loss: 0.629083
# GAN loss: 4.811288
# Step 72 completed. Time took: 6 secs.
# Begin step:  73
# Disc: real loss: 0.343539 fake loss: 0.398792
# GAN loss: 1.817948
# Step 73 completed. Time took: 6 secs.
# Begin step:  74
# Disc: real loss: 0.348574 fake loss: 1.023724
# GAN loss: 7.556532
# Step 74 completed. Time took: 6 secs.
# Begin step:  75
# Disc: real loss: 0.682497 fake loss: 1.036132
# GAN loss: 7.808796
# Step 75 completed. Time took: 6 secs.
# Begin step:  76
# Disc: real loss: 0.451771 fake loss: 0.751994
# GAN loss: 3.651002
# Step 76 completed. Time took: 6 secs.
# Begin step:  77
# Disc: real loss: 0.436485 fake loss: 0.415912
# GAN loss: 1.668215
# Step 77 completed. Time took: 6 secs.
# Begin step:  78
# Disc: real loss: 0.387607 fake loss: 0.463180
# GAN loss: 2.858050
# Step 78 completed. Time took: 6 secs.
# Begin step:  79
# Disc: real loss: 0.373440 fake loss: 0.379276
# GAN loss: 2.494798
# Step 79 completed. Time took: 6 secs.
# Begin step:  80
# Disc: real loss: 0.370081 fake loss: 0.365290
# GAN loss: 2.086043
# Step 80 completed. Time took: 6 secs.
# Begin step:  81
# Disc: real loss: 0.337568 fake loss: 0.402080
# GAN loss: 2.784982
# Step 81 completed. Time took: 6 secs.
# Begin step:  82
# Disc: real loss: 0.357851 fake loss: 0.335599
# GAN loss: 2.601534
# Step 82 completed. Time took: 6 secs.
# Begin step:  83
# Disc: real loss: 0.370670 fake loss: 0.362446
# GAN loss: 2.478480
# Step 83 completed. Time took: 7 secs.
# Begin step:  84
# Disc: real loss: 0.370839 fake loss: 0.409551
# GAN loss: 2.633414
# Step 84 completed. Time took: 6 secs.
# Begin step:  85
# Disc: real loss: 0.345726 fake loss: 0.363464
# GAN loss: 2.355985
# Step 85 completed. Time took: 6 secs.
# Begin step:  86
# Disc: real loss: 0.363612 fake loss: 0.415725
# GAN loss: 3.014791
# Step 86 completed. Time took: 6 secs.
# Begin step:  87
# Disc: real loss: 0.349243 fake loss: 0.319415
# GAN loss: 2.582130
# Step 87 completed. Time took: 6 secs.
# Begin step:  88
# Disc: real loss: 0.332490 fake loss: 0.324322
# GAN loss: 2.290070
# Step 88 completed. Time took: 6 secs.
# Begin step:  89
# Disc: real loss: 0.344018 fake loss: 0.341104
# GAN loss: 2.116157
# Step 89 completed. Time took: 6 secs.
# Begin step:  90
# Disc: real loss: 0.349288 fake loss: 0.422004
# GAN loss: 3.370711
# Step 90 completed. Time took: 6 secs.
# Begin step:  91
# Disc: real loss: 0.425839 fake loss: 0.352236
# GAN loss: 1.942476
# Step 91 completed. Time took: 6 secs.
# Begin step:  92
# Disc: real loss: 0.333907 fake loss: 0.487125
# GAN loss: 2.946554
# Step 92 completed. Time took: 6 secs.
# Begin step:  93
# Disc: real loss: 0.437010 fake loss: 0.368280
# GAN loss: 2.569296
# Step 93 completed. Time took: 6 secs.
# Begin step:  94
# Disc: real loss: 0.339904 fake loss: 0.361353
# GAN loss: 2.734237
# Step 94 completed. Time took: 6 secs.
# Begin step:  95
# Disc: real loss: 0.332605 fake loss: 0.339363
# GAN loss: 2.106907
# Step 95 completed. Time took: 6 secs.
# Begin step:  96
# Disc: real loss: 0.370060 fake loss: 0.384944
# GAN loss: 2.568080
# Step 96 completed. Time took: 6 secs.
# Begin step:  97
# Disc: real loss: 0.430764 fake loss: 0.377573
# GAN loss: 2.542851
# Step 97 completed. Time took: 6 secs.
# Begin step:  98
# Disc: real loss: 0.367995 fake loss: 0.368169
# GAN loss: 2.308614
# Step 98 completed. Time took: 6 secs.
# Begin step:  99
# Disc: real loss: 0.361466 fake loss: 0.323559
# GAN loss: 2.574858
# Step 99 completed. Time took: 6 secs.
# Begin step:  100
# Disc: real loss: 0.423795 fake loss: 0.377266
# GAN loss: 2.304133
# Step 100 completed. Time took: 7 secs.
# Begin step:  101
# Disc: real loss: 0.363251 fake loss: 0.344299
# GAN loss: 2.592265
# Step 101 completed. Time took: 6 secs.
# Begin step:  102
# Disc: real loss: 0.350247 fake loss: 0.358670
# GAN loss: 2.441927
# Step 102 completed. Time took: 7 secs.
# Begin step:  103
# Disc: real loss: 0.326479 fake loss: 0.336175
# GAN loss: 2.479594
# Step 103 completed. Time took: 6 secs.
# Begin step:  104
# Disc: real loss: 0.371265 fake loss: 0.394615
# GAN loss: 3.031697
# Step 104 completed. Time took: 6 secs.
# Begin step:  105
# Disc: real loss: 0.447388 fake loss: 0.372429
# GAN loss: 2.811643
# Step 105 completed. Time took: 6 secs.
# Begin step:  106
# Disc: real loss: 0.598750 fake loss: 0.851517
# GAN loss: 3.835590
# Step 106 completed. Time took: 6 secs.
# Begin step:  107
# Disc: real loss: 0.690953 fake loss: 0.379870
# GAN loss: 2.315347
# Step 107 completed. Time took: 6 secs.
# Begin step:  108
# Disc: real loss: 0.459579 fake loss: 0.525048
# GAN loss: 3.640018
# Step 108 completed. Time took: 6 secs.
# Begin step:  109
# Disc: real loss: 0.385885 fake loss: 0.445758
# GAN loss: 3.485156
# Step 109 completed. Time took: 6 secs.
# Begin step:  110
# Disc: real loss: 0.463404 fake loss: 0.421766
# GAN loss: 2.657771
# Step 110 completed. Time took: 6 secs.
# Begin step:  111
# Disc: real loss: 0.403898 fake loss: 0.359290
# GAN loss: 2.151002
# Step 111 completed. Time took: 6 secs.
# Begin step:  112
# Disc: real loss: 0.351828 fake loss: 0.402604
# GAN loss: 3.021922
# Step 112 completed. Time took: 6 secs.
# Begin step:  113
# Disc: real loss: 0.352887 fake loss: 0.338120
# GAN loss: 2.100101
# Step 113 completed. Time took: 6 secs.
# Begin step:  114
# Disc: real loss: 0.346889 fake loss: 0.383692
# GAN loss: 2.708703
# Step 114 completed. Time took: 6 secs.
# Begin step:  115
# Disc: real loss: 0.375031 fake loss: 0.343148
# GAN loss: 2.214130
# Step 115 completed. Time took: 6 secs.
# Begin step:  116
# Disc: real loss: 0.356772 fake loss: 0.409715
# GAN loss: 3.230699
# Step 116 completed. Time took: 6 secs.
# Begin step:  117
# Disc: real loss: 0.423690 fake loss: 0.370628
# GAN loss: 1.881196
# Step 117 completed. Time took: 6 secs.
# Begin step:  118
# Disc: real loss: 0.369914 fake loss: 0.445655
# GAN loss: 3.309248
# Step 118 completed. Time took: 6 secs.
# Begin step:  119
# Disc: real loss: 0.363172 fake loss: 0.408431
# GAN loss: 2.579931
# Step 119 completed. Time took: 6 secs.
# Begin step:  120
# Disc: real loss: 0.352798 fake loss: 0.398524
# GAN loss: 2.111491
# Step 120 completed. Time took: 6 secs.
# Begin step:  121
# Disc: real loss: 0.385160 fake loss: 0.359866
# GAN loss: 2.305131
# Step 121 completed. Time took: 6 secs.
# Begin step:  122
# Disc: real loss: 0.368276 fake loss: 0.355443
# GAN loss: 3.273908
# Step 122 completed. Time took: 6 secs.
# Begin step:  123
# Disc: real loss: 0.401641 fake loss: 0.383220
# GAN loss: 2.287684
# Step 123 completed. Time took: 6 secs.
# Begin step:  124
# Disc: real loss: 0.368600 fake loss: 0.535033
# GAN loss: 4.030164
# Step 124 completed. Time took: 6 secs.
# Begin step:  125
# Disc: real loss: 0.449168 fake loss: 0.359227
# GAN loss: 2.668056
# Step 125 completed. Time took: 6 secs.
# Begin step:  126
# Disc: real loss: 0.356079 fake loss: 0.454825
# GAN loss: 3.791973
# Step 126 completed. Time took: 6 secs.
# Begin step:  127
# Disc: real loss: 0.427563 fake loss: 0.388930
# GAN loss: 2.948659
# Step 127 completed. Time took: 6 secs.
# Begin step:  128
# Disc: real loss: 0.333896 fake loss: 0.387749
# GAN loss: 2.718521
# Step 128 completed. Time took: 6 secs.
# Begin step:  129
# Disc: real loss: 0.381418 fake loss: 0.372279
# GAN loss: 2.318845
# Step 129 completed. Time took: 6 secs.
# Begin step:  130
# Disc: real loss: 0.316657 fake loss: 0.344620
# GAN loss: 2.735496
# Step 130 completed. Time took: 6 secs.
# Begin step:  131
# Disc: real loss: 0.387968 fake loss: 0.442414
# GAN loss: 3.231202
# Step 131 completed. Time took: 7 secs.
# Begin step:  132
# Disc: real loss: 0.369556 fake loss: 0.432119
# GAN loss: 3.038881
# Step 132 completed. Time took: 8 secs.
# Begin step:  133
# Disc: real loss: 0.357729 fake loss: 0.379305
# GAN loss: 1.790784
# Step 133 completed. Time took: 7 secs.
# Begin step:  134
# Disc: real loss: 0.356883 fake loss: 0.466460
# GAN loss: 3.568821
# Step 134 completed. Time took: 6 secs.
# Begin step:  135
# Disc: real loss: 0.355296 fake loss: 0.489038
# GAN loss: 3.030698
# Step 135 completed. Time took: 6 secs.
# Begin step:  136
# Disc: real loss: 0.339787 fake loss: 0.307804
# GAN loss: 2.013906
# Step 136 completed. Time took: 6 secs.
# Begin step:  137
# Disc: real loss: 0.369463 fake loss: 0.369758
# GAN loss: 2.458348
# Step 137 completed. Time took: 6 secs.
# Begin step:  138
# Disc: real loss: 0.363192 fake loss: 0.361298
# GAN loss: 2.267484
# Step 138 completed. Time took: 6 secs.
# Begin step:  139
# Disc: real loss: 0.402744 fake loss: 0.414939
# GAN loss: 2.818660
# Step 139 completed. Time took: 6 secs.
# Begin step:  140
# Disc: real loss: 0.371178 fake loss: 0.379856
# GAN loss: 2.506967
# Step 140 completed. Time took: 6 secs.
# Begin step:  141
# Disc: real loss: 0.344037 fake loss: 0.317928
# GAN loss: 2.133041
# Step 141 completed. Time took: 6 secs.
# Begin step:  142
# Disc: real loss: 0.345066 fake loss: 0.422073
# GAN loss: 3.196129
# Step 142 completed. Time took: 6 secs.
# Begin step:  143
# Disc: real loss: 0.355099 fake loss: 0.478107
# GAN loss: 2.616269
# Step 143 completed. Time took: 6 secs.
# Begin step:  144
# Disc: real loss: 0.356484 fake loss: 0.380800
# GAN loss: 2.795811
# Step 144 completed. Time took: 7 secs.
# Begin step:  145
# Disc: real loss: 0.414431 fake loss: 0.339389
# GAN loss: 2.172242
# Step 145 completed. Time took: 9 secs.
# Begin step:  146
# Disc: real loss: 0.366464 fake loss: 0.348745
# GAN loss: 2.943696
# Step 146 completed. Time took: 9 secs.
# Begin step:  147
# Disc: real loss: 0.349313 fake loss: 0.369888
# GAN loss: 2.011940
# Step 147 completed. Time took: 7 secs.
# Begin step:  148
# Disc: real loss: 0.349533 fake loss: 0.395195
# GAN loss: 3.069770
# Step 148 completed. Time took: 7 secs.
# Begin step:  149
# Disc: real loss: 0.394554 fake loss: 0.383807
# GAN loss: 2.294770
# Step 149 completed. Time took: 6 secs.
# Begin step:  150
# Disc: real loss: 0.343683 fake loss: 0.389750
# GAN loss: 3.322246
# Step 150 completed. Time took: 7 secs.
# Begin step:  151
# Disc: real loss: 0.408004 fake loss: 0.460968
# GAN loss: 2.181355
# Step 151 completed. Time took: 6 secs.
# Begin step:  152
# Disc: real loss: 0.407222 fake loss: 0.447666
# GAN loss: 3.097701
# Step 152 completed. Time took: 6 secs.
# Begin step:  153
# Disc: real loss: 0.448727 fake loss: 0.342237
# GAN loss: 2.167610
# Step 153 completed. Time took: 6 secs.
# Begin step:  154
# Disc: real loss: 0.339153 fake loss: 0.388313
# GAN loss: 2.883622
# Step 154 completed. Time took: 6 secs.
# Begin step:  155
# Disc: real loss: 0.355236 fake loss: 0.381657
# GAN loss: 2.475647
# Step 155 completed. Time took: 6 secs.
# Begin step:  156
# Disc: real loss: 0.342161 fake loss: 0.379797
# GAN loss: 2.430764
# Step 156 completed. Time took: 6 secs.
# Begin step:  157
# Disc: real loss: 0.351322 fake loss: 0.316294
# GAN loss: 2.643838
# Step 157 completed. Time took: 6 secs.
# Begin step:  158
# Disc: real loss: 0.337782 fake loss: 0.338181
# GAN loss: 2.046129
# Step 158 completed. Time took: 6 secs.
# Begin step:  159
# Disc: real loss: 0.397596 fake loss: 0.535617
# GAN loss: 3.999854
# Step 159 completed. Time took: 6 secs.
# Begin step:  160
# Disc: real loss: 0.357702 fake loss: 0.512939
# GAN loss: 4.082003
# Step 160 completed. Time took: 6 secs.
# Begin step:  161
# Disc: real loss: 0.346532 fake loss: 0.464283
# GAN loss: 2.158103
# Step 161 completed. Time took: 6 secs.
# Begin step:  162
# Disc: real loss: 0.453779 fake loss: 0.810681
# GAN loss: 4.730581
# Step 162 completed. Time took: 6 secs.
# Begin step:  163
# Disc: real loss: 0.400996 fake loss: 0.561182
# GAN loss: 4.953436
# Step 163 completed. Time took: 7 secs.
# Begin step:  164
# Disc: real loss: 0.430949 fake loss: 0.356530
# GAN loss: 2.132457
# Step 164 completed. Time took: 6 secs.
# Begin step:  165
# Disc: real loss: 0.412686 fake loss: 0.498456
# GAN loss: 3.129071
# Step 165 completed. Time took: 6 secs.
# Begin step:  166
# Disc: real loss: 0.506929 fake loss: 0.365058
# GAN loss: 2.375892
# Step 166 completed. Time took: 6 secs.
# Begin step:  167
# Disc: real loss: 0.410650 fake loss: 0.468949
# GAN loss: 3.027432
# Step 167 completed. Time took: 6 secs.
# Begin step:  168
# Disc: real loss: 0.382228 fake loss: 0.416693
# GAN loss: 3.072986
# Step 168 completed. Time took: 6 secs.
# Begin step:  169
# Disc: real loss: 0.339503 fake loss: 0.363846
# GAN loss: 2.439775
# Step 169 completed. Time took: 6 secs.
# Begin step:  170
# Disc: real loss: 0.329011 fake loss: 0.439444
# GAN loss: 3.277873
# Step 170 completed. Time took: 7 secs.
# Begin step:  171
# Disc: real loss: 0.428350 fake loss: 0.409367
# GAN loss: 2.552704
# Step 171 completed. Time took: 6 secs.
# Begin step:  172
# Disc: real loss: 0.361094 fake loss: 0.375488
# GAN loss: 2.482471
# Step 172 completed. Time took: 6 secs.
# Begin step:  173
# Disc: real loss: 0.351330 fake loss: 0.302734
# GAN loss: 2.463741
# Step 173 completed. Time took: 6 secs.
# Begin step:  174
# Disc: real loss: 0.383254 fake loss: 0.331832
# GAN loss: 2.116590
# Step 174 completed. Time took: 6 secs.
# Begin step:  175
# Disc: real loss: 0.328465 fake loss: 0.320327
# GAN loss: 2.722769
# Step 175 completed. Time took: 6 secs.
# Begin step:  176
# Disc: real loss: 0.411563 fake loss: 0.340312
# GAN loss: 2.002707
# Step 176 completed. Time took: 6 secs.
# Begin step:  177
# Disc: real loss: 0.357583 fake loss: 0.439398
# GAN loss: 3.955826
# Step 177 completed. Time took: 6 secs.
# Begin step:  178
# Disc: real loss: 0.455859 fake loss: 0.415621
# GAN loss: 2.651532
# Step 178 completed. Time took: 6 secs.
# Begin step:  179
# Disc: real loss: 0.385603 fake loss: 0.379121
# GAN loss: 1.962631
# Step 179 completed. Time took: 6 secs.
# Begin step:  180
# Disc: real loss: 0.341898 fake loss: 0.364915
# GAN loss: 2.678970
# Step 180 completed. Time took: 6 secs.
# Begin step:  181
# Disc: real loss: 0.385333 fake loss: 0.333586
# GAN loss: 2.374718
# Step 181 completed. Time took: 7 secs.
# Begin step:  182
# Disc: real loss: 0.362703 fake loss: 0.349692
# GAN loss: 2.075902
# Step 182 completed. Time took: 7 secs.
# Begin step:  183
# Disc: real loss: 0.330637 fake loss: 0.409375
# GAN loss: 3.290372
# Step 183 completed. Time took: 6 secs.
# Begin step:  184
# Disc: real loss: 0.393900 fake loss: 0.335830
# GAN loss: 2.598348
# Step 184 completed. Time took: 6 secs.
# Begin step:  185
# Disc: real loss: 0.404681 fake loss: 0.637948
# GAN loss: 4.201470
# Step 185 completed. Time took: 6 secs.
# Begin step:  186
# Disc: real loss: 0.409266 fake loss: 0.584369
# GAN loss: 3.615354
# Step 186 completed. Time took: 6 secs.
# Begin step:  187
# Disc: real loss: 0.404779 fake loss: 0.352741
# GAN loss: 2.108742
# Step 187 completed. Time took: 6 secs.
# Begin step:  188
# Disc: real loss: 0.347527 fake loss: 0.370945
# GAN loss: 2.255837
# Step 188 completed. Time took: 6 secs.
# Begin step:  189
# Disc: real loss: 0.347334 fake loss: 0.353962
# GAN loss: 2.321458
# Step 189 completed. Time took: 6 secs.
# Begin step:  190
# Disc: real loss: 0.375650 fake loss: 0.362784
# GAN loss: 2.103203
# Step 190 completed. Time took: 6 secs.
# Begin step:  191
# Disc: real loss: 0.339224 fake loss: 0.349946
# GAN loss: 2.213404
# Step 191 completed. Time took: 6 secs.
# Begin step:  192
# Disc: real loss: 0.348977 fake loss: 0.344229
# GAN loss: 2.125583
# Step 192 completed. Time took: 7 secs.
# Begin step:  193
# Disc: real loss: 0.356890 fake loss: 0.350511
# GAN loss: 1.877418
# Step 193 completed. Time took: 6 secs.
# Begin step:  194
# Disc: real loss: 0.366920 fake loss: 0.376476
# GAN loss: 2.939617
# Step 194 completed. Time took: 6 secs.
# Begin step:  195
# Disc: real loss: 0.418081 fake loss: 0.362613
# GAN loss: 2.051501
# Step 195 completed. Time took: 6 secs.
# Begin step:  196
# Disc: real loss: 0.547989 fake loss: 1.063791
# GAN loss: 4.527939
# Step 196 completed. Time took: 7 secs.
# Begin step:  197
# Disc: real loss: 0.680542 fake loss: 0.454413
# GAN loss: 3.606630
# Step 197 completed. Time took: 6 secs.
# Begin step:  198
# Disc: real loss: 0.512217 fake loss: 0.402246
# GAN loss: 2.402726
# Step 198 completed. Time took: 6 secs.
# Begin step:  199
# Disc: real loss: 0.414609 fake loss: 0.402151
# GAN loss: 2.375379
# Step 199 completed. Time took: 7 secs.
# Begin step:  200
# Disc: real loss: 0.377551 fake loss: 0.333653
# GAN loss: 1.948792
# Step 200 completed. Time took: 7 secs.
# Begin step:  201
# Disc: real loss: 0.374476 fake loss: 0.541300
# GAN loss: 3.514534
# Step 201 completed. Time took: 7 secs.
# Begin step:  202
# Disc: real loss: 0.425752 fake loss: 0.442337
# GAN loss: 3.065600
# Step 202 completed. Time took: 8 secs.
# Begin step:  203
# Disc: real loss: 0.382830 fake loss: 0.401463
# GAN loss: 2.239982
# Step 203 completed. Time took: 6 secs.
# Begin step:  204
# Disc: real loss: 0.338725 fake loss: 0.350679
# GAN loss: 2.528727
# Step 204 completed. Time took: 6 secs.
# Begin step:  205
# Disc: real loss: 0.355469 fake loss: 0.333963
# GAN loss: 2.306585
# Step 205 completed. Time took: 6 secs.
# Begin step:  206
# Disc: real loss: 0.348644 fake loss: 0.372825
# GAN loss: 1.520935
# Step 206 completed. Time took: 6 secs.
# Begin step:  207
# Disc: real loss: 0.388266 fake loss: 0.362421
# GAN loss: 2.592147
# Step 207 completed. Time took: 6 secs.
# Begin step:  208
# Disc: real loss: 0.380666 fake loss: 0.352293
# GAN loss: 1.919673
# Step 208 completed. Time took: 6 secs.
# Begin step:  209
# Disc: real loss: 0.349166 fake loss: 0.400963
# GAN loss: 2.757329
# Step 209 completed. Time took: 6 secs.
# Begin step:  210
# Disc: real loss: 0.610816 fake loss: 0.428398
# GAN loss: 2.432201
# Step 210 completed. Time took: 6 secs.
# Begin step:  211
# Disc: real loss: 0.380222 fake loss: 0.341336
# GAN loss: 2.809984
# Step 211 completed. Time took: 6 secs.
# Begin step:  212
# Disc: real loss: 0.375990 fake loss: 0.424394
# GAN loss: 3.045299
# Step 212 completed. Time took: 6 secs.
# Begin step:  213
# Disc: real loss: 0.457771 fake loss: 0.391730
# GAN loss: 2.637178
# Step 213 completed. Time took: 6 secs.
# Begin step:  214
# Disc: real loss: 0.381363 fake loss: 0.349443
# GAN loss: 2.330226
# Step 214 completed. Time took: 6 secs.
# Begin step:  215
# Disc: real loss: 0.361902 fake loss: 0.346115
# GAN loss: 2.544518
# Step 215 completed. Time took: 6 secs.
# Begin step:  216
# Disc: real loss: 0.372534 fake loss: 0.321874
# GAN loss: 1.836617
# Step 216 completed. Time took: 7 secs.
# Begin step:  217
# Disc: real loss: 0.376181 fake loss: 0.398565
# GAN loss: 2.344168
# Step 217 completed. Time took: 7 secs.
# Begin step:  218
# Disc: real loss: 0.401964 fake loss: 0.439948
# GAN loss: 3.335842
# Step 218 completed. Time took: 6 secs.
# Begin step:  219
# Disc: real loss: 0.380489 fake loss: 0.361791
# GAN loss: 2.139147
# Step 219 completed. Time took: 6 secs.
# Begin step:  220
# Disc: real loss: 0.331683 fake loss: 0.347709
# GAN loss: 2.207511
# Step 220 completed. Time took: 6 secs.
# Begin step:  221
# Disc: real loss: 0.355050 fake loss: 0.348080
# GAN loss: 2.290688
# Step 221 completed. Time took: 6 secs.
# Begin step:  222
# Disc: real loss: 0.331847 fake loss: 0.321707
# GAN loss: 2.252263
# Step 222 completed. Time took: 6 secs.
# Begin step:  223
# Disc: real loss: 0.331108 fake loss: 0.395017
# GAN loss: 2.964118
# Step 223 completed. Time took: 6 secs.
# Begin step:  224
# Disc: real loss: 0.532664 fake loss: 0.503366
# GAN loss: 3.166058
# Step 224 completed. Time took: 6 secs.
# Begin step:  225
# Disc: real loss: 0.404809 fake loss: 0.402603
# GAN loss: 3.264845
# Step 225 completed. Time took: 6 secs.
# Begin step:  226
# Disc: real loss: 0.351079 fake loss: 0.356585
# GAN loss: 2.279598
# Step 226 completed. Time took: 6 secs.
# Begin step:  227
# Disc: real loss: 0.415904 fake loss: 0.373799
# GAN loss: 3.375525
# Step 227 completed. Time took: 6 secs.
# Begin step:  228
# Disc: real loss: 0.542572 fake loss: 0.362030
# GAN loss: 2.448288
# Step 228 completed. Time took: 6 secs.
# Begin step:  229
# Disc: real loss: 0.393928 fake loss: 0.356312
# GAN loss: 2.313572
# Step 229 completed. Time took: 6 secs.
# Begin step:  230
# Disc: real loss: 0.350038 fake loss: 0.348675
# GAN loss: 2.627245
# Step 230 completed. Time took: 6 secs.
# Begin step:  231
# Disc: real loss: 0.370216 fake loss: 0.323419
# GAN loss: 2.229656
# Step 231 completed. Time took: 6 secs.
# Begin step:  232
# Disc: real loss: 0.331939 fake loss: 0.392481
# GAN loss: 2.276641
# Step 232 completed. Time took: 6 secs.
# Begin step:  233
# Disc: real loss: 0.452916 fake loss: 0.594013
# GAN loss: 4.022722
# Step 233 completed. Time took: 6 secs.
# Begin step:  234
# Disc: real loss: 0.455994 fake loss: 0.440459
# GAN loss: 3.015018
# Step 234 completed. Time took: 6 secs.
# Begin step:  235
# Disc: real loss: 0.395357 fake loss: 0.359986
# GAN loss: 2.229146
# Step 235 completed. Time took: 6 secs.
# Begin step:  236
# Disc: real loss: 0.375161 fake loss: 0.403935
# GAN loss: 3.185344
# Step 236 completed. Time took: 6 secs.
# Begin step:  237
# Disc: real loss: 0.428182 fake loss: 0.299766
# GAN loss: 2.658048
# Step 237 completed. Time took: 6 secs.
# Begin step:  238
# Disc: real loss: 0.407527 fake loss: 0.396339
# GAN loss: 2.619363
# Step 238 completed. Time took: 6 secs.
# Begin step:  239
# Disc: real loss: 0.363821 fake loss: 0.367299
# GAN loss: 2.250982
# Step 239 completed. Time took: 6 secs.
# Begin step:  240
# Disc: real loss: 0.350858 fake loss: 0.343841
# GAN loss: 2.703457
# Step 240 completed. Time took: 6 secs.
# Begin step:  241
# Disc: real loss: 0.362614 fake loss: 0.348388
# GAN loss: 2.360573
# Step 241 completed. Time took: 6 secs.
# Begin step:  242
# Disc: real loss: 0.348564 fake loss: 0.348153
# GAN loss: 2.403336
# Step 242 completed. Time took: 6 secs.
# Begin step:  243
# Disc: real loss: 0.345016 fake loss: 0.359151
# GAN loss: 1.893054
# Step 243 completed. Time took: 6 secs.
# Begin step:  244
# Disc: real loss: 0.364973 fake loss: 0.385321
# GAN loss: 2.879134
# Step 244 completed. Time took: 6 secs.
# Begin step:  245
# Disc: real loss: 0.426048 fake loss: 0.348868
# GAN loss: 2.627589
# Step 245 completed. Time took: 6 secs.
# Begin step:  246
# Disc: real loss: 0.378488 fake loss: 0.398077
# GAN loss: 3.030936
# Step 246 completed. Time took: 6 secs.
# Begin step:  247
# Disc: real loss: 0.545248 fake loss: 0.442568
# GAN loss: 3.309748
# Step 247 completed. Time took: 6 secs.
# Begin step:  248
# Disc: real loss: 0.359922 fake loss: 0.359818
# GAN loss: 2.764188
# Step 248 completed. Time took: 6 secs.
# Begin step:  249
# Disc: real loss: 0.375641 fake loss: 0.404773
# GAN loss: 2.869862
# Step 249 completed. Time took: 6 secs.
# Begin step:  250
# Disc: real loss: 0.442354 fake loss: 0.376535
# GAN loss: 2.546997
# Step 250 completed. Time took: 6 secs.
# Begin step:  251
# Disc: real loss: 0.401414 fake loss: 0.418961
# GAN loss: 2.903928
# Step 251 completed. Time took: 6 secs.
# Begin step:  252
# Disc: real loss: 0.343232 fake loss: 0.406484
# GAN loss: 2.413822
# Step 252 completed. Time took: 6 secs.
# Begin step:  253
# Disc: real loss: 0.330631 fake loss: 0.370227
# GAN loss: 2.442959
# Step 253 completed. Time took: 6 secs.
# Begin step:  254
# Disc: real loss: 0.364254 fake loss: 0.322819
# GAN loss: 2.243868
# Step 254 completed. Time took: 7 secs.
# Begin step:  255
# Disc: real loss: 0.321491 fake loss: 0.418020
# GAN loss: 2.840051
# Step 255 completed. Time took: 8 secs.
# Begin step:  256
# Disc: real loss: 0.369637 fake loss: 0.362147
# GAN loss: 2.234944
# Step 256 completed. Time took: 7 secs.
# Begin step:  257
# Disc: real loss: 0.358037 fake loss: 0.406136
# GAN loss: 2.641735
# Step 257 completed. Time took: 7 secs.
# Begin step:  258
# Disc: real loss: 0.336057 fake loss: 0.321274
# GAN loss: 2.660718
# Step 258 completed. Time took: 113 secs.
# Begin step:  259
# Disc: real loss: 0.322881 fake loss: 0.351242
# GAN loss: 2.529953
# Step 259 completed. Time took: 8 secs.
# Begin step:  260
# Disc: real loss: 0.357001 fake loss: 0.351262
# GAN loss: 2.150231
# Step 260 completed. Time took: 5 secs.
# Begin step:  261
# Disc: real loss: 0.357339 fake loss: 0.481758
# GAN loss: 4.163504
# Step 261 completed. Time took: 5 secs.
# Begin step:  262
# Disc: real loss: 0.426894 fake loss: 0.443465
# GAN loss: 2.782766
# Step 262 completed. Time took: 4 secs.
# Begin step:  263
# Disc: real loss: 0.336206 fake loss: 0.394362
# GAN loss: 3.126705
# Step 263 completed. Time took: 4 secs.
# Begin step:  264
# Disc: real loss: 0.365023 fake loss: 0.359471
# GAN loss: 2.253356
# Step 264 completed. Time took: 4 secs.
# Begin step:  265
# Disc: real loss: 0.383421 fake loss: 0.386368
# GAN loss: 2.656968
# Step 265 completed. Time took: 4 secs.
# Begin step:  266
# Disc: real loss: 0.414889 fake loss: 0.393194
# GAN loss: 2.420265
# Step 266 completed. Time took: 5 secs.
# Begin step:  267
# Disc: real loss: 0.367132 fake loss: 0.347533
# GAN loss: 2.736739
# Step 267 completed. Time took: 5 secs.
# Begin step:  268
# Disc: real loss: 0.360690 fake loss: 0.339313
# GAN loss: 2.582414
# Step 268 completed. Time took: 5 secs.
# Begin step:  269
# Disc: real loss: 0.313541 fake loss: 0.338560
# GAN loss: 1.983846
# Step 269 completed. Time took: 5 secs.
# Begin step:  270
# Disc: real loss: 0.332911 fake loss: 0.457002
# GAN loss: 4.164473
# Step 270 completed. Time took: 4 secs.
# Begin step:  271
# Disc: real loss: 0.377936 fake loss: 0.483969
# GAN loss: 2.688582
# Step 271 completed. Time took: 4 secs.
# Begin step:  272
# Disc: real loss: 0.392331 fake loss: 0.596920
# GAN loss: 4.861455
# Step 272 completed. Time took: 4 secs.
# Begin step:  273
# Disc: real loss: 0.486679 fake loss: 0.603568
# GAN loss: 3.887083
# Step 273 completed. Time took: 4 secs.
# Begin step:  274
# Disc: real loss: 0.490758 fake loss: 0.379915
# GAN loss: 2.462952
# Step 274 completed. Time took: 4 secs.
# Begin step:  275
# Disc: real loss: 0.357065 fake loss: 0.382104
# GAN loss: 3.285095
# Step 275 completed. Time took: 4 secs.
# Begin step:  276
# Disc: real loss: 0.406705 fake loss: 0.322853
# GAN loss: 2.401926
# Step 276 completed. Time took: 4 secs.
# Begin step:  277
# Disc: real loss: 0.378119 fake loss: 0.381836
# GAN loss: 2.424647
# Step 277 completed. Time took: 4 secs.
# Begin step:  278
# Disc: real loss: 0.354661 fake loss: 0.353732
# GAN loss: 2.591994
# Step 278 completed. Time took: 4 secs.
# Begin step:  279
# Disc: real loss: 0.378002 fake loss: 0.344628
# GAN loss: 2.148358
# Step 279 completed. Time took: 4 secs.
# Begin step:  280
# Disc: real loss: 0.343069 fake loss: 0.302406
# GAN loss: 2.451363
# Step 280 completed. Time took: 4 secs.
# Begin step:  281
# Disc: real loss: 0.421227 fake loss: 0.475450
# GAN loss: 3.630729
# Step 281 completed. Time took: 4 secs.
# Begin step:  282
# Disc: real loss: 0.373481 fake loss: 0.506301
# GAN loss: 3.768425
# Step 282 completed. Time took: 4 secs.
# Begin step:  283
# Disc: real loss: 0.384536 fake loss: 0.411603
# GAN loss: 2.084930
# Step 283 completed. Time took: 4 secs.
# Begin step:  284
# Disc: real loss: 0.324117 fake loss: 0.435221
# GAN loss: 3.149164
# Step 284 completed. Time took: 4 secs.
# Begin step:  285
# Disc: real loss: 0.439430 fake loss: 0.355410
# GAN loss: 2.429023
# Step 285 completed. Time took: 4 secs.
# Begin step:  286
# Disc: real loss: 0.377839 fake loss: 0.342329
# GAN loss: 1.969939
# Step 286 completed. Time took: 4 secs.
# Begin step:  287
# Disc: real loss: 0.346528 fake loss: 0.369294
# GAN loss: 3.151937
# Step 287 completed. Time took: 4 secs.
# Begin step:  288
# Disc: real loss: 0.385987 fake loss: 0.377127
# GAN loss: 2.313404
# Step 288 completed. Time took: 4 secs.
# Begin step:  289
# Disc: real loss: 0.353756 fake loss: 0.363261
# GAN loss: 2.538404
# Step 289 completed. Time took: 4 secs.
# Begin step:  290
# Disc: real loss: 0.349497 fake loss: 0.338624
# GAN loss: 2.481184
# Step 290 completed. Time took: 4 secs.
# Begin step:  291
# Disc: real loss: 0.424211 fake loss: 0.469179
# GAN loss: 2.668202
# Step 291 completed. Time took: 4 secs.
# Begin step:  292
# Disc: real loss: 0.312902 fake loss: 0.396730
# GAN loss: 2.881712
# Step 292 completed. Time took: 5 secs.
# Begin step:  293
# Disc: real loss: 0.366139 fake loss: 0.335236
# GAN loss: 2.889799
# Step 293 completed. Time took: 4 secs.
# Begin step:  294
# Disc: real loss: 0.346398 fake loss: 0.362872
# GAN loss: 3.011429
# Step 294 completed. Time took: 4 secs.
# Begin step:  295
# Disc: real loss: 0.338261 fake loss: 0.335096
# GAN loss: 2.123605
# Step 295 completed. Time took: 4 secs.
# Begin step:  296
# Disc: real loss: 0.319722 fake loss: 0.351333
# GAN loss: 2.587947
# Step 296 completed. Time took: 4 secs.
# Begin step:  297
# Disc: real loss: 0.355571 fake loss: 0.338255
# GAN loss: 2.260402
# Step 297 completed. Time took: 4 secs.
# Begin step:  298
# Disc: real loss: 0.377699 fake loss: 0.356210
# GAN loss: 1.732901
# Step 298 completed. Time took: 4 secs.
# Begin step:  299
# Disc: real loss: 0.365913 fake loss: 0.328583
# GAN loss: 1.903443
# Step 299 completed. Time took: 4 secs.
# Begin step:  300
# Disc: real loss: 0.386370 fake loss: 0.358370
# GAN loss: 2.618980
# Step 300 completed. Time took: 4 secs.
# Begin step:  301
# Disc: real loss: 0.385142 fake loss: 0.367110
# GAN loss: 2.573267
# Step 301 completed. Time took: 4 secs.
# Begin step:  302
# Disc: real loss: 0.336329 fake loss: 0.386708
# GAN loss: 2.437539
# Step 302 completed. Time took: 4 secs.
# Begin step:  303
# Disc: real loss: 0.353638 fake loss: 0.364108
# GAN loss: 2.466042
# Step 303 completed. Time took: 4 secs.
# Begin step:  304
# Disc: real loss: 0.353629 fake loss: 0.293335
# GAN loss: 2.272527
# Step 304 completed. Time took: 4 secs.
# Begin step:  305
# Disc: real loss: 0.364592 fake loss: 0.398219
# GAN loss: 3.334090
# Step 305 completed. Time took: 4 secs.
# Begin step:  306
# Disc: real loss: 0.375623 fake loss: 0.368861
# GAN loss: 2.451003
# Step 306 completed. Time took: 4 secs.
# Begin step:  307
# Disc: real loss: 0.339902 fake loss: 0.397860
# GAN loss: 3.397297
# Step 307 completed. Time took: 5 secs.
# Begin step:  308
# Disc: real loss: 0.434649 fake loss: 0.379782
# GAN loss: 1.874790
# Step 308 completed. Time took: 4 secs.
# Begin step:  309
# Disc: real loss: 0.356136 fake loss: 0.393224
# GAN loss: 3.126490
# Step 309 completed. Time took: 4 secs.
# Begin step:  310
# Disc: real loss: 0.364928 fake loss: 0.367728
# GAN loss: 2.739411
# Step 310 completed. Time took: 4 secs.
# Begin step:  311
# Disc: real loss: 0.373973 fake loss: 0.384700
# GAN loss: 1.768338
# Step 311 completed. Time took: 4 secs.
# Begin step:  312
# Disc: real loss: 0.348290 fake loss: 0.446912
# GAN loss: 3.620433
# Step 312 completed. Time took: 4 secs.
# Begin step:  313
# Disc: real loss: 0.361970 fake loss: 0.408744
# GAN loss: 3.101706
# Step 313 completed. Time took: 4 secs.
# Begin step:  314
# Disc: real loss: 0.327799 fake loss: 0.344244
# GAN loss: 2.107968
# Step 314 completed. Time took: 4 secs.
# Begin step:  315
# Disc: real loss: 0.356524 fake loss: 0.334272
# GAN loss: 2.996424
# Step 315 completed. Time took: 4 secs.
# Begin step:  316
# Disc: real loss: 0.352519 fake loss: 0.373817
# GAN loss: 2.056376
# Step 316 completed. Time took: 4 secs.
# Begin step:  317
# Disc: real loss: 0.308829 fake loss: 0.372772
# GAN loss: 3.032845
# Step 317 completed. Time took: 4 secs.
# Begin step:  318
# Disc: real loss: 0.356792 fake loss: 0.354000
# GAN loss: 2.846170
# Step 318 completed. Time took: 4 secs.
# Begin step:  319
# Disc: real loss: 0.335644 fake loss: 0.383241
# GAN loss: 3.209015
# Step 319 completed. Time took: 4 secs.
# Begin step:  320
# Disc: real loss: 0.387900 fake loss: 0.354101
# GAN loss: 2.095211
# Step 320 completed. Time took: 4 secs.
# Begin step:  321
# Disc: real loss: 0.323909 fake loss: 0.368237
# GAN loss: 2.943283
# Step 321 completed. Time took: 5 secs.
# Begin step:  322
# Disc: real loss: 0.347377 fake loss: 0.333665
# GAN loss: 2.175672
# Step 322 completed. Time took: 4 secs.
# Begin step:  323
# Disc: real loss: 0.338710 fake loss: 0.346604
# GAN loss: 3.196568
# Step 323 completed. Time took: 4 secs.
# Begin step:  324
# Disc: real loss: 0.387855 fake loss: 0.342127
# GAN loss: 2.445548
# Step 324 completed. Time took: 4 secs.
# Begin step:  325
# Disc: real loss: 0.339318 fake loss: 0.360692
# GAN loss: 2.841468
# Step 325 completed. Time took: 4 secs.
# Begin step:  326
# Disc: real loss: 0.364149 fake loss: 0.376835
# GAN loss: 2.515407
# Step 326 completed. Time took: 4 secs.
# Begin step:  327
# Disc: real loss: 0.327635 fake loss: 0.404311
# GAN loss: 3.587044
# Step 327 completed. Time took: 4 secs.
# Begin step:  328
# Disc: real loss: 0.375294 fake loss: 0.381235
# GAN loss: 2.979545
# Step 328 completed. Time took: 4 secs.
# Begin step:  329
# Disc: real loss: 0.346106 fake loss: 0.338116
# GAN loss: 2.725452
# Step 329 completed. Time took: 4 secs.
# Begin step:  330
# Disc: real loss: 0.336139 fake loss: 0.332370
# GAN loss: 2.473753
# Step 330 completed. Time took: 5 secs.
# Begin step:  331
# Disc: real loss: 0.333174 fake loss: 0.362599
# GAN loss: 2.480488
# Step 331 completed. Time took: 4 secs.
# Begin step:  332
# Disc: real loss: 0.411478 fake loss: 0.467487
# GAN loss: 3.799299
# Step 332 completed. Time took: 4 secs.
# Begin step:  333
# Disc: real loss: 0.394524 fake loss: 0.478036
# GAN loss: 2.425828
# Step 333 completed. Time took: 5 secs.
# Begin step:  334
# Disc: real loss: 0.334486 fake loss: 0.453883
# GAN loss: 3.413651
# Step 334 completed. Time took: 8 secs.
# Begin step:  335
# Disc: real loss: 0.447539 fake loss: 0.458241
# GAN loss: 2.601527
# Step 335 completed. Time took: 9 secs.
# Begin step:  336
# Disc: real loss: 0.374407 fake loss: 0.376086
# GAN loss: 2.516142
# Step 336 completed. Time took: 7 secs.
# Begin step:  337
# Disc: real loss: 0.351159 fake loss: 0.336096
# GAN loss: 2.187633
# Step 337 completed. Time took: 7 secs.
# Begin step:  338
# Disc: real loss: 0.360128 fake loss: 0.406725
# GAN loss: 3.509752
# Step 338 completed. Time took: 7 secs.
# Begin step:  339
# Disc: real loss: 0.403259 fake loss: 0.343586
# GAN loss: 2.484561
# Step 339 completed. Time took: 7 secs.
# Begin step:  340
# Disc: real loss: 0.393657 fake loss: 0.356577
# GAN loss: 2.777768
# Step 340 completed. Time took: 7 secs.
# Begin step:  341
# Disc: real loss: 0.345737 fake loss: 0.356314
# GAN loss: 2.647419
# Step 341 completed. Time took: 7 secs.
# Begin step:  342
# Disc: real loss: 0.385816 fake loss: 0.388479
# GAN loss: 2.607743
# Step 342 completed. Time took: 7 secs.
# Begin step:  343
# Disc: real loss: 0.307490 fake loss: 0.334227
# GAN loss: 2.672046
# Step 343 completed. Time took: 7 secs.
# Begin step:  344
# Disc: real loss: 0.338204 fake loss: 0.334846
# GAN loss: 2.164370
# Step 344 completed. Time took: 7 secs.
# Begin step:  345
# Disc: real loss: 0.307067 fake loss: 0.364656
# GAN loss: 2.628786
# Step 345 completed. Time took: 7 secs.
# Begin step:  346
# Disc: real loss: 0.336557 fake loss: 0.352134
# GAN loss: 2.387044
# Step 346 completed. Time took: 8 secs.
# Begin step:  347
# Disc: real loss: 0.361784 fake loss: 0.350241
# GAN loss: 2.202141
# Step 347 completed. Time took: 8 secs.
# Begin step:  348
# Disc: real loss: 0.315999 fake loss: 0.380336
# GAN loss: 2.980236
# Step 348 completed. Time took: 8 secs.
# Begin step:  349
# Disc: real loss: 0.321465 fake loss: 0.362872
# GAN loss: 2.128154
# Step 349 completed. Time took: 7 secs.
# Begin step:  350
# Disc: real loss: 0.344584 fake loss: 0.479608
# GAN loss: 3.790089
# Step 350 completed. Time took: 6 secs.
# Begin step:  351
# Disc: real loss: 0.402287 fake loss: 0.405146
# GAN loss: 2.595903
# Step 351 completed. Time took: 6 secs.
# Begin step:  352
# Disc: real loss: 0.355025 fake loss: 0.398033
# GAN loss: 2.907550
# Step 352 completed. Time took: 6 secs.
# Begin step:  353
# Disc: real loss: 0.327583 fake loss: 0.372849
# GAN loss: 2.689882
# Step 353 completed. Time took: 6 secs.
# Begin step:  354
# Disc: real loss: 0.364677 fake loss: 0.323323
# GAN loss: 2.679233
# Step 354 completed. Time took: 6 secs.
# Begin step:  355
# Disc: real loss: 0.377740 fake loss: 0.388676
# GAN loss: 3.577992
# Step 355 completed. Time took: 6 secs.
# Begin step:  356
# Disc: real loss: 0.342890 fake loss: 0.464051
# GAN loss: 2.669190
# Step 356 completed. Time took: 6 secs.
# Begin step:  357
# Disc: real loss: 0.354719 fake loss: 0.363503
# GAN loss: 2.418119
# Step 357 completed. Time took: 6 secs.
# Begin step:  358
# Disc: real loss: 0.354652 fake loss: 0.373860
# GAN loss: 2.353272
# Step 358 completed. Time took: 6 secs.
# Begin step:  359
# Disc: real loss: 0.353839 fake loss: 0.407740
# GAN loss: 3.508251
# Step 359 completed. Time took: 6 secs.
# Begin step:  360
# Disc: real loss: 0.473308 fake loss: 0.372535
# GAN loss: 1.626425
# Step 360 completed. Time took: 6 secs.
# Begin step:  361
# Disc: real loss: 0.373425 fake loss: 0.425863
# GAN loss: 3.129737
# Step 361 completed. Time took: 6 secs.
# Begin step:  362
# Disc: real loss: 0.345618 fake loss: 0.407394
# GAN loss: 2.819801
# Step 362 completed. Time took: 6 secs.
# Begin step:  363
# Disc: real loss: 0.382297 fake loss: 0.397037
# GAN loss: 2.722109
# Step 363 completed. Time took: 6 secs.
# Begin step:  364
# Disc: real loss: 0.397771 fake loss: 0.371634
# GAN loss: 2.610459
# Step 364 completed. Time took: 6 secs.
# Begin step:  365
# Disc: real loss: 0.403459 fake loss: 0.366334
# GAN loss: 2.862451
# Step 365 completed. Time took: 5 secs.
# Begin step:  366
# Disc: real loss: 0.369615 fake loss: 0.385847
# GAN loss: 2.852305
# Step 366 completed. Time took: 5 secs.
# Begin step:  367
# Disc: real loss: 0.401200 fake loss: 0.366620
# GAN loss: 1.792818
# Step 367 completed. Time took: 6 secs.
# Begin step:  368
# Disc: real loss: 0.345941 fake loss: 0.358433
# GAN loss: 2.180294
# Step 368 completed. Time took: 5 secs.
# Begin step:  369
# Disc: real loss: 0.311636 fake loss: 0.384448
# GAN loss: 2.725661
# Step 369 completed. Time took: 5 secs.
# Begin step:  370
# Disc: real loss: 0.365079 fake loss: 0.338865
# GAN loss: 2.033633
# Step 370 completed. Time took: 5 secs.
# Begin step:  371
# Disc: real loss: 0.415997 fake loss: 0.373929
# GAN loss: 3.413839
# Step 371 completed. Time took: 5 secs.
# Begin step:  372
# Disc: real loss: 0.389844 fake loss: 0.361021
# GAN loss: 2.472094
# Step 372 completed. Time took: 5 secs.
# Begin step:  373
# Disc: real loss: 0.376933 fake loss: 0.368074
# GAN loss: 2.585569
# Step 373 completed. Time took: 5 secs.
# Begin step:  374
# Disc: real loss: 0.371687 fake loss: 0.328363
# GAN loss: 2.196562
# Step 374 completed. Time took: 5 secs.
# Begin step:  375
# Disc: real loss: 0.312196 fake loss: 0.337452
# GAN loss: 2.359515
# Step 375 completed. Time took: 5 secs.
# Begin step:  376
# Disc: real loss: 0.299899 fake loss: 0.351222
# GAN loss: 2.364635
# Step 376 completed. Time took: 5 secs.
# Begin step:  377
# Disc: real loss: 0.316172 fake loss: 0.348509
# GAN loss: 1.797358
# Step 377 completed. Time took: 5 secs.
# Begin step:  378
# Disc: real loss: 0.373148 fake loss: 0.358528
# GAN loss: 2.798787
# Step 378 completed. Time took: 5 secs.
# Begin step:  379
# Disc: real loss: 0.404835 fake loss: 0.395598
# GAN loss: 2.557053
# Step 379 completed. Time took: 5 secs.
# Begin step:  380
# Disc: real loss: 0.387901 fake loss: 0.366127
# GAN loss: 2.368374
# Step 380 completed. Time took: 5 secs.
# Begin step:  381
# Disc: real loss: 0.367665 fake loss: 0.364662
# GAN loss: 2.522237
# Step 381 completed. Time took: 5 secs.
# Begin step:  382
# Disc: real loss: 0.396436 fake loss: 0.374079
# GAN loss: 2.326695
# Step 382 completed. Time took: 5 secs.
# Begin step:  383
# Disc: real loss: 0.392472 fake loss: 0.366002
# GAN loss: 2.100988
# Step 383 completed. Time took: 5 secs.
# Begin step:  384
# Disc: real loss: 0.371697 fake loss: 0.396984
# GAN loss: 2.179048
# Step 384 completed. Time took: 5 secs.
# Begin step:  385
# Disc: real loss: 0.344167 fake loss: 0.389940
# GAN loss: 2.267072
# Step 385 completed. Time took: 6 secs.
# Begin step:  386
# Disc: real loss: 0.416202 fake loss: 0.582480
# GAN loss: 4.920599
# Step 386 completed. Time took: 5 secs.
# Begin step:  387
# Disc: real loss: 0.716959 fake loss: 0.495601
# GAN loss: 3.319805
# Step 387 completed. Time took: 5 secs.
# Begin step:  388
# Disc: real loss: 0.457755 fake loss: 0.402050
# GAN loss: 2.269788
# Step 388 completed. Time took: 5 secs.
# Begin step:  389
# Disc: real loss: 0.394134 fake loss: 0.453404
# GAN loss: 3.514855
# Step 389 completed. Time took: 5 secs.
# Begin step:  390
# Disc: real loss: 0.383083 fake loss: 0.498147
# GAN loss: 2.728820
# Step 390 completed. Time took: 5 secs.
# Begin step:  391
# Disc: real loss: 0.341033 fake loss: 0.351309
# GAN loss: 2.085511
# Step 391 completed. Time took: 5 secs.
# Begin step:  392
# Disc: real loss: 0.364630 fake loss: 0.477915
# GAN loss: 4.633394
# Step 392 completed. Time took: 5 secs.
# Begin step:  393
# Disc: real loss: 0.644630 fake loss: 0.356170
# GAN loss: 1.594318
# Step 393 completed. Time took: 5 secs.
# Begin step:  394
# Disc: real loss: 0.455841 fake loss: 0.458781
# GAN loss: 4.189799
# Step 394 completed. Time took: 5 secs.
# Begin step:  395
# Disc: real loss: 0.567098 fake loss: 0.349268
# GAN loss: 1.645897
# Step 395 completed. Time took: 5 secs.
# Begin step:  396
# Disc: real loss: 0.462447 fake loss: 0.438192
# GAN loss: 3.869291
# Step 396 completed. Time took: 5 secs.
# Begin step:  397
# Disc: real loss: 0.401388 fake loss: 0.409298
# GAN loss: 2.957961
# Step 397 completed. Time took: 6 secs.
# Begin step:  398
# Disc: real loss: 0.386988 fake loss: 0.319929
# GAN loss: 2.217406
# Step 398 completed. Time took: 5 secs.
# Begin step:  399
# Disc: real loss: 0.379379 fake loss: 0.380378
# GAN loss: 2.497123
# Step 399 completed. Time took: 5 secs.
# Begin step:  400
# Disc: real loss: 0.370419 fake loss: 0.380186
# GAN loss: 2.135205
# Step 400 completed. Time took: 7 secs.
# Begin step:  401
# Disc: real loss: 0.359328 fake loss: 0.340899
# GAN loss: 2.112208
# Step 401 completed. Time took: 7 secs.
# Begin step:  402
# Disc: real loss: 0.392606 fake loss: 0.342154
# GAN loss: 2.296204
# Step 402 completed. Time took: 6 secs.
# Begin step:  403
# Disc: real loss: 0.369681 fake loss: 0.446414
# GAN loss: 3.259496
# Step 403 completed. Time took: 7 secs.
# Begin step:  404
# Disc: real loss: 0.355428 fake loss: 0.386934
# GAN loss: 3.128814
# Step 404 completed. Time took: 7 secs.
# Begin step:  405
# Disc: real loss: 0.340718 fake loss: 0.348828
# GAN loss: 1.980994
# Step 405 completed. Time took: 7 secs.
# Begin step:  406
# Disc: real loss: 0.313517 fake loss: 0.361452
# GAN loss: 2.174551
# Step 406 completed. Time took: 7 secs.
# Begin step:  407
# Disc: real loss: 0.352802 fake loss: 0.383117
# GAN loss: 3.175436
# Step 407 completed. Time took: 7 secs.
# Begin step:  408
# Disc: real loss: 0.432626 fake loss: 0.323579
# GAN loss: 1.970499
# Step 408 completed. Time took: 7 secs.
# Begin step:  409
# Disc: real loss: 0.325440 fake loss: 0.331186
# GAN loss: 2.397027
# Step 409 completed. Time took: 7 secs.
# Begin step:  410
# Disc: real loss: 0.330037 fake loss: 0.324621
# GAN loss: 2.644577
# Step 410 completed. Time took: 7 secs.
# Begin step:  411
# Disc: real loss: 0.333357 fake loss: 0.343413
# GAN loss: 2.024631
# Step 411 completed. Time took: 6 secs.
# Begin step:  412
# Disc: real loss: 0.347501 fake loss: 0.347176
# GAN loss: 2.186443
# Step 412 completed. Time took: 6 secs.
# Begin step:  413
# Disc: real loss: 0.357555 fake loss: 0.370633
# GAN loss: 2.909195
# Step 413 completed. Time took: 6 secs.
# Begin step:  414
# Disc: real loss: 0.395090 fake loss: 0.384006
# GAN loss: 2.270023
# Step 414 completed. Time took: 6 secs.
# Begin step:  415
# Disc: real loss: 0.378907 fake loss: 0.362304
# GAN loss: 2.409645
# Step 415 completed. Time took: 6 secs.
# Begin step:  416
# Disc: real loss: 0.339822 fake loss: 0.342243
# GAN loss: 2.605161
# Step 416 completed. Time took: 6 secs.
# Begin step:  417
# Disc: real loss: 0.335888 fake loss: 0.322579
# GAN loss: 2.347730
# Step 417 completed. Time took: 6 secs.
# Begin step:  418
# Disc: real loss: 0.399152 fake loss: 0.354915
# GAN loss: 2.111721
# Step 418 completed. Time took: 6 secs.
# Begin step:  419
# Disc: real loss: 0.404311 fake loss: 0.369226
# GAN loss: 2.758452
# Step 419 completed. Time took: 6 secs.
# Begin step:  420
# Disc: real loss: 0.350635 fake loss: 0.351166
# GAN loss: 2.043600
# Step 420 completed. Time took: 6 secs.
# Begin step:  421
# Disc: real loss: 0.425227 fake loss: 0.649010
# GAN loss: 4.939852
# Step 421 completed. Time took: 6 secs.
# Begin step:  422
# Disc: real loss: 0.471230 fake loss: 0.523380
# GAN loss: 3.230872
# Step 422 completed. Time took: 7 secs.
# Begin step:  423
# Disc: real loss: 0.368852 fake loss: 0.379875
# GAN loss: 2.950796
# Step 423 completed. Time took: 7 secs.
# Begin step:  424
# Disc: real loss: 0.396423 fake loss: 0.366301
# GAN loss: 2.542093
# Step 424 completed. Time took: 7 secs.
# Begin step:  425
# Disc: real loss: 0.346723 fake loss: 0.386779
# GAN loss: 3.306514
# Step 425 completed. Time took: 7 secs.
# Begin step:  426
# Disc: real loss: 0.430550 fake loss: 0.338769
# GAN loss: 1.924652
# Step 426 completed. Time took: 7 secs.
# Begin step:  427
# Disc: real loss: 0.348100 fake loss: 0.322552
# GAN loss: 2.731803
# Step 427 completed. Time took: 7 secs.
# Begin step:  428
# Disc: real loss: 0.313373 fake loss: 0.358673
# GAN loss: 2.446318
# Step 428 completed. Time took: 7 secs.
# Begin step:  429
# Disc: real loss: 0.333703 fake loss: 0.368673
# GAN loss: 2.592427
# Step 429 completed. Time took: 7 secs.
# Begin step:  430
# Disc: real loss: 0.369478 fake loss: 0.394734
# GAN loss: 2.475971
# Step 430 completed. Time took: 7 secs.
# Begin step:  431
# Disc: real loss: 0.369010 fake loss: 0.383535
# GAN loss: 2.583350
# Step 431 completed. Time took: 7 secs.
# Begin step:  432
# Disc: real loss: 0.346727 fake loss: 0.368177
# GAN loss: 2.898649
# Step 432 completed. Time took: 7 secs.
# Begin step:  433
# Disc: real loss: 0.374131 fake loss: 0.354538
# GAN loss: 2.382961
# Step 433 completed. Time took: 7 secs.
# Begin step:  434
# Disc: real loss: 0.385146 fake loss: 0.338716
# GAN loss: 2.234932
# Step 434 completed. Time took: 7 secs.
# Begin step:  435
# Disc: real loss: 0.350239 fake loss: 0.383854
# GAN loss: 3.372064
# Step 435 completed. Time took: 6 secs.
# Begin step:  436
# Disc: real loss: 0.387924 fake loss: 0.320231
# GAN loss: 2.267931
# Step 436 completed. Time took: 6 secs.
# Begin step:  437
# Disc: real loss: 0.346260 fake loss: 0.352216
# GAN loss: 2.463737
# Step 437 completed. Time took: 6 secs.
# Begin step:  438
# Disc: real loss: 0.335004 fake loss: 0.334728
# GAN loss: 2.643336
# Step 438 completed. Time took: 6 secs.
# Begin step:  439
# Disc: real loss: 0.327329 fake loss: 0.329250
# GAN loss: 2.549846
# Step 439 completed. Time took: 5 secs.
# Begin step:  440
# Disc: real loss: 0.339337 fake loss: 0.342761
# GAN loss: 1.881021
# Step 440 completed. Time took: 6 secs.
# Begin step:  441
# Disc: real loss: 0.356189 fake loss: 0.353357
# GAN loss: 2.977286
# Step 441 completed. Time took: 5 secs.
# Begin step:  442
# Disc: real loss: 0.390737 fake loss: 0.378320
# GAN loss: 2.116375
# Step 442 completed. Time took: 6 secs.
# Begin step:  443
# Disc: real loss: 0.341855 fake loss: 0.403640
# GAN loss: 3.721224
# Step 443 completed. Time took: 6 secs.
# Begin step:  444
# Disc: real loss: 0.487894 fake loss: 0.387125
# GAN loss: 2.119140
# Step 444 completed. Time took: 6 secs.
# Begin step:  445
# Disc: real loss: 0.377173 fake loss: 0.380475
# GAN loss: 3.217832
# Step 445 completed. Time took: 5 secs.
# Begin step:  446
# Disc: real loss: 0.373095 fake loss: 0.414791
# GAN loss: 2.531232
# Step 446 completed. Time took: 5 secs.
# Begin step:  447
# Disc: real loss: 0.367251 fake loss: 0.362974
# GAN loss: 2.552718
# Step 447 completed. Time took: 5 secs.
# Begin step:  448
# Disc: real loss: 0.379390 fake loss: 0.400685
# GAN loss: 2.496577
# Step 448 completed. Time took: 5 secs.
# Begin step:  449
# Disc: real loss: 0.328402 fake loss: 0.368567
# GAN loss: 2.647852
# Step 449 completed. Time took: 5 secs.
# Begin step:  450
# Disc: real loss: 0.346373 fake loss: 0.348314
# GAN loss: 2.042777
# Step 450 completed. Time took: 5 secs.
# Begin step:  451
# Disc: real loss: 0.346727 fake loss: 0.331752
# GAN loss: 2.173183
# Step 451 completed. Time took: 5 secs.
# Begin step:  452
# Disc: real loss: 0.399651 fake loss: 0.390822
# GAN loss: 2.498665
# Step 452 completed. Time took: 6 secs.
# Begin step:  453
# Disc: real loss: 0.429288 fake loss: 0.397015
# GAN loss: 2.392596
# Step 453 completed. Time took: 5 secs.
# Begin step:  454
# Disc: real loss: 0.370802 fake loss: 0.352541
# GAN loss: 2.484943
# Step 454 completed. Time took: 5 secs.
# Begin step:  455
# Disc: real loss: 0.387564 fake loss: 0.359504
# GAN loss: 2.333679
# Step 455 completed. Time took: 5 secs.
# Begin step:  456
# Disc: real loss: 0.356916 fake loss: 0.396958
# GAN loss: 3.316493
# Step 456 completed. Time took: 5 secs.
# Begin step:  457
# Disc: real loss: 0.366401 fake loss: 0.397118
